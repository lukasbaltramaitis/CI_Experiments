# %% [markdown]
# # BPIC log preparation for experiments

# %% [markdown]
# ## Dependencies

# %%
import pandas as pd
from preparation import save_csv, read_csv, Preparation
import networkx as nx
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Constants

# %%
DATASET_PATH = r'/Users/lukas/Desktop/CI_Experiments/CI_Experiments/data/unprepared_process_logs/BPIC17_O_Accepted.csv'
TRUE_GRAPH_PATH = r'C:\Users\Lukas\CI_Experiments\CI_Experiments\data\prepared_process_logs\BPIC_17\true_graph.csv'
DATA_1_TRAIN_PATH = r'C:\Users\Lukas\CI_Experiments\CI_Experiments\data\prepared_process_logs\BPIC_17\activities\train.csv'
DATA_1_TEST_PATH = r'C:\Users\Lukas\CI_Experiments\CI_Experiments\data\prepared_process_logs\BPIC_17\activities\test.csv'
DATA_2_TRAIN_PATH = r'/Users/lukas/Desktop/CI_Experiments/CI_Experiments/data/prepared_process_logs/BPIC_17/activities_numeric2/train.csv'
DATA_2_TEST_PATH = r'/Users/lukas/Desktop/CI_Experiments/CI_Experiments/data/prepared_process_logs/BPIC_17/activities_numeric2/test.csv'
CASE_ID = 'Case ID'
ACTIVITY = 'Activity'
LABEL = 'label'
OUTCOME = 'Outcome'
TIMESTAMP = 'time:timestamp'

# %% [markdown]
# ## Code

# %%
data = read_csv(path=DATASET_PATH)
data.head()
# Out:
#   ApplicationType                LoanGoal  RequestedAmount  \
# 0      New credit  Existing loan takeover          20000.0
# 1      New credit  Existing loan takeover          20000.0
# 2      New credit  Existing loan takeover          20000.0
# 3      New credit  Existing loan takeover          20000.0
# 4      New credit  Existing loan takeover          20000.0
#
#                  Case ID    label                Activity org:resource  \
# 0  Application_652823628  deviant    A_Create Application       User_1
# 1  Application_652823628  deviant             A_Submitted       User_1
# 2  Application_652823628  deviant          W_Handle leads       User_1
# 3  Application_652823628  deviant          W_Handle leads       User_1
# 4  Application_652823628  deviant  W_Complete application       User_1
#
#         Action  EventOrigin lifecycle:transition  ... CreditScore  \
# 0      Created  Application             complete  ...         0.0
# 1  statechange  Application             complete  ...         0.0
# 2      Created     Workflow             schedule  ...         0.0
# 3      Deleted     Workflow             withdraw  ...         0.0
# 4      Created     Workflow             schedule  ...         0.0
#
#   timesincelastevent  timesincecasestart  timesincemidnight  event_nr  month  \
# 0           0.000000            0.000000                591         1      1
# 1           0.000800            0.000800                591         2      1
# 2           0.007033            0.007833                591         3      1
# 3           1.343633            1.351467                592         4      1
# 4           0.000183            1.351650                592         5      1
#
#    weekday  hour  open_cases           time:timestamp
# 0        4     9           0  2016-01-01 09:51:15.304
# 1        4     9           1  2016-01-01 09:51:15.352
# 2        4     9           1  2016-01-01 09:51:15.774
# 3        4     9           1  2016-01-01 09:52:36.392
# 4        4     9           1  2016-01-01 09:52:36.403
#
# [5 rows x 26 columns]

# %%
data = data.sort_values([CASE_ID, TIMESTAMP])

# %% [markdown]
# ### 1 Preparation (Only Activities (v1) + Outcome)

# %%
data1 = data.copy()
data1.columns
# Out:
# Index(['ApplicationType', 'LoanGoal', 'RequestedAmount', 'Case ID', 'label',
#        'Activity', 'org:resource', 'Action', 'EventOrigin',
#        'lifecycle:transition', 'Accepted', 'Selected', 'FirstWithdrawalAmount',
#        'MonthlyCost', 'NumberOfTerms', 'OfferedAmount', 'CreditScore',
#        'timesincelastevent', 'timesincecasestart', 'timesincemidnight',
#        'event_nr', 'month', 'weekday', 'hour', 'open_cases', 'time:timestamp'],
#       dtype='object')

# %%
data1 = data1[[CASE_ID, ACTIVITY, LABEL]]
data1.head()
# Out:
#                        Case ID                Activity    label
# 686058  Application_1000086665    A_Create Application  regular
# 686059  Application_1000086665             A_Submitted  regular
# 686060  Application_1000086665          W_Handle leads  regular
# 686061  Application_1000086665          W_Handle leads  regular
# 686062  Application_1000086665  W_Complete application  regular

# %%
data1[OUTCOME] = np.where(data1[LABEL]=='deviant', 1, 0)
data1.head()
# Out:
#                        Case ID                Activity    label  Outcome
# 686058  Application_1000086665    A_Create Application  regular        0
# 686059  Application_1000086665             A_Submitted  regular        0
# 686060  Application_1000086665          W_Handle leads  regular        0
# 686061  Application_1000086665          W_Handle leads  regular        0
# 686062  Application_1000086665  W_Complete application  regular        0

# %%
data1 = data1[[CASE_ID, ACTIVITY, OUTCOME]]
data1.head()
# Out:
#                        Case ID                Activity  Outcome
# 686058  Application_1000086665    A_Create Application        0
# 686059  Application_1000086665             A_Submitted        0
# 686060  Application_1000086665          W_Handle leads        0
# 686061  Application_1000086665          W_Handle leads        0
# 686062  Application_1000086665  W_Complete application        0

# %%
preparation = Preparation(data1)

# %%
preparation.create_activity_graph(path=TRUE_GRAPH_PATH)

# %%
preparation.encode(columns_to_encode=[ACTIVITY])
preparation.encoded_data.head()
# Out:
#                         Outcome  Activity_A_Accepted  Activity_A_Cancelled  \
# Case ID
# Application_1000086665      0.0                  1.0                   0.0
# Application_1000158214      1.0                  0.0                   0.0
# Application_1000311556      0.0                  0.0                   0.0
# Application_1000334415      0.0                  1.0                   0.0
# Application_1000339879      1.0                  1.0                   1.0
#
#                         Activity_A_Complete  Activity_A_Concept  \
# Case ID
# Application_1000086665                  0.0                 1.0
# Application_1000158214                  0.0                 0.0
# Application_1000311556                  0.0                 0.0
# Application_1000334415                  1.0                 1.0
# Application_1000339879                  1.0                 1.0
#
#                         Activity_A_Create Application  Activity_A_Denied  \
# Case ID
# Application_1000086665                            1.0                0.0
# Application_1000158214                            0.0                0.0
# Application_1000311556                            0.0                0.0
# Application_1000334415                            1.0                0.0
# Application_1000339879                            1.0                0.0
#
#                         Activity_A_Incomplete  Activity_A_Pending  \
# Case ID
# Application_1000086665                    0.0                 1.0
# Application_1000158214                    1.0                 0.0
# Application_1000311556                    0.0                 0.0
# Application_1000334415                    1.0                 1.0
# Application_1000339879                    0.0                 1.0
#
#                         Activity_A_Submitted  ...  \
# Case ID                                       ...
# Application_1000086665                   1.0  ...
# Application_1000158214                   0.0  ...
# Application_1000311556                   0.0  ...
# Application_1000334415                   1.0  ...
# Application_1000339879                   1.0  ...
#
#                         Activity_O_Sent (mail and online)  \
# Case ID
# Application_1000086665                                1.0
# Application_1000158214                                0.0
# Application_1000311556                                0.0
# Application_1000334415                                1.0
# Application_1000339879                                1.0
#
#                         Activity_O_Sent (online only)  \
# Case ID
# Application_1000086665                            1.0
# Application_1000158214                            1.0
# Application_1000311556                            1.0
# Application_1000334415                            0.0
# Application_1000339879                            0.0
#
#                         Activity_W_Assess potential fraud  \
# Case ID
# Application_1000086665                                0.0
# Application_1000158214                                0.0
# Application_1000311556                                0.0
# Application_1000334415                                0.0
# Application_1000339879                                0.0
#
#                         Activity_W_Call after offers  \
# Case ID
# Application_1000086665                           1.0
# Application_1000158214                           1.0
# Application_1000311556                           0.0
# Application_1000334415                           1.0
# Application_1000339879                           1.0
#
#                         Activity_W_Call incomplete files  \
# Case ID
# Application_1000086665                               1.0
# Application_1000158214                               1.0
# Application_1000311556                               1.0
# Application_1000334415                               1.0
# Application_1000339879                               0.0
#
#                         Activity_W_Complete application  \
# Case ID
# Application_1000086665                              1.0
# Application_1000158214                              0.0
# Application_1000311556                              0.0
# Application_1000334415                              1.0
# Application_1000339879                              1.0
#
#                         Activity_W_Handle leads  \
# Case ID
# Application_1000086665                      1.0
# Application_1000158214                      0.0
# Application_1000311556                      0.0
# Application_1000334415                      1.0
# Application_1000339879                      1.0
#
#                         Activity_W_Personal Loan collection  \
# Case ID
# Application_1000086665                                  0.0
# Application_1000158214                                  0.0
# Application_1000311556                                  0.0
# Application_1000334415                                  0.0
# Application_1000339879                                  0.0
#
#                         Activity_W_Shortened completion   \
# Case ID
# Application_1000086665                               0.0
# Application_1000158214                               0.0
# Application_1000311556                               0.0
# Application_1000334415                               0.0
# Application_1000339879                               0.0
#
#                         Activity_W_Validate application
# Case ID
# Application_1000086665                              0.0
# Application_1000158214                              1.0
# Application_1000311556                              1.0
# Application_1000334415                              1.0
# Application_1000339879                              1.0
#
# [5 rows x 27 columns]

# %%
encoded_data = preparation.encoded_data
X_train, X_test = train_test_split(encoded_data, test_size=0.2, random_state=42)

# %%
save_csv(X_train, DATA_1_TRAIN_PATH)
save_csv(X_test, DATA_1_TEST_PATH)

# %% [markdown]
# ### 2 Preparation (All + Outcome)

# %%
data2 = data.copy()
data2.head()
# Out:
#        ApplicationType                LoanGoal  RequestedAmount  \
# 686058      New credit  Other, see explanation           5000.0
# 686059      New credit  Other, see explanation           5000.0
# 686060      New credit  Other, see explanation           5000.0
# 686061      New credit  Other, see explanation           5000.0
# 686062      New credit  Other, see explanation           5000.0
#
#                        Case ID    label                Activity org:resource  \
# 686058  Application_1000086665  regular    A_Create Application       User_1
# 686059  Application_1000086665  regular             A_Submitted       User_1
# 686060  Application_1000086665  regular          W_Handle leads       User_1
# 686061  Application_1000086665  regular          W_Handle leads       User_1
# 686062  Application_1000086665  regular  W_Complete application       User_1
#
#              Action  EventOrigin lifecycle:transition  ... CreditScore  \
# 686058      Created  Application             complete  ...         0.0
# 686059  statechange  Application             complete  ...         0.0
# 686060      Created     Workflow             schedule  ...         0.0
# 686061      Deleted     Workflow             withdraw  ...         0.0
# 686062      Created     Workflow             schedule  ...         0.0
#
#        timesincelastevent  timesincecasestart  timesincemidnight  event_nr  \
# 686058           0.000000            0.000000                957         1
# 686059           0.001017            0.001017                957         2
# 686060           0.003817            0.004833                957         3
# 686061           1.105383            1.110217                958         4
# 686062           0.000117            1.110333                958         5
#
#         month  weekday  hour  open_cases           time:timestamp
# 686058      8        2    15        2249  2016-08-03 15:57:21.673
# 686059      8        2    15        2250  2016-08-03 15:57:21.734
# 686060      8        2    15        2250  2016-08-03 15:57:21.963
# 686061      8        2    15        2250  2016-08-03 15:58:28.286
# 686062      8        2    15        2250  2016-08-03 15:58:28.293
#
# [5 rows x 26 columns]

# %%
data2.columns
# Out:
# Index(['ApplicationType', 'LoanGoal', 'RequestedAmount', 'Case ID', 'label',
#        'Activity', 'org:resource', 'Action', 'EventOrigin',
#        'lifecycle:transition', 'Accepted', 'Selected', 'FirstWithdrawalAmount',
#        'MonthlyCost', 'NumberOfTerms', 'OfferedAmount', 'CreditScore',
#        'timesincelastevent', 'timesincecasestart', 'timesincemidnight',
#        'event_nr', 'month', 'weekday', 'hour', 'open_cases', 'time:timestamp'],
#       dtype='object')

# %%
data2.dtypes
# Out:
# ApplicationType           object
# LoanGoal                  object
# RequestedAmount          float64
# Case ID                   object
# label                     object
# Activity                  object
# org:resource              object
# Action                    object
# EventOrigin               object
# lifecycle:transition      object
# Accepted                  object
# Selected                  object
# FirstWithdrawalAmount    float64
# MonthlyCost              float64
# NumberOfTerms            float64
# OfferedAmount            float64
# CreditScore              float64
# timesincelastevent       float64
# timesincecasestart       float64
# timesincemidnight          int64
# event_nr                   int64
# month                      int64
# weekday                    int64
# hour                       int64
# open_cases                 int64
# time:timestamp            object
# dtype: object

# %%
numeric_columns = ['RequestedAmount', 'FirstWithdrawalAmount', 'MonthlyCost', 'NumberOfTerms', 
'OfferedAmount', 'CreditScore', 'open_cases']
columns_to_take = [CASE_ID, ACTIVITY, LABEL] + numeric_columns

# %%
data2 = data2[columns_to_take]
data2[OUTCOME] = np.where(data2[LABEL]=='deviant', 1, 0)
data2 = data2.drop(columns=[LABEL])
data2.head()
# Out:
#                        Case ID                Activity  RequestedAmount  \
# 686058  Application_1000086665    A_Create Application           5000.0
# 686059  Application_1000086665             A_Submitted           5000.0
# 686060  Application_1000086665          W_Handle leads           5000.0
# 686061  Application_1000086665          W_Handle leads           5000.0
# 686062  Application_1000086665  W_Complete application           5000.0
#
#         FirstWithdrawalAmount  MonthlyCost  NumberOfTerms  OfferedAmount  \
# 686058                    0.0          0.0            0.0            0.0
# 686059                    0.0          0.0            0.0            0.0
# 686060                    0.0          0.0            0.0            0.0
# 686061                    0.0          0.0            0.0            0.0
# 686062                    0.0          0.0            0.0            0.0
#
#         CreditScore  open_cases  Outcome
# 686058          0.0        2249        0
# 686059          0.0        2250        0
# 686060          0.0        2250        0
# 686061          0.0        2250        0
# 686062          0.0        2250        0

# %%
preparation2 = Preparation(data2)

# %%
preparation2.target_encode(columns_to_encode=[ACTIVITY])
preparation2.encoded_data.head()
# Out:
#                         RequestedAmount  FirstWithdrawalAmount  MonthlyCost  \
# Case ID
# Application_1000086665           5000.0                 5000.0       241.28
# Application_1000158214          12500.0                    0.0       250.00
# Application_1000311556          45000.0                    0.0       500.00
# Application_1000334415           5000.0                 5000.0       152.82
# Application_1000339879          37500.0                    0.0       375.00
#
#                         NumberOfTerms  OfferedAmount  CreditScore  open_cases  \
# Case ID
# Application_1000086665           22.0         5000.0          0.0      2306.0
# Application_1000158214           57.0        12500.0        929.0      1659.0
# Application_1000311556          111.0        45000.0          0.0      1564.0
# Application_1000334415           36.0         5000.0          0.0      2679.0
# Application_1000339879          126.0        37500.0        798.0      1720.0
#
#                         Outcome  Activity_A_Accepted  Activity_A_Cancelled  \
# Case ID
# Application_1000086665      0.0             0.400061              0.000000
# Application_1000158214      1.0             0.000000              0.000000
# Application_1000311556      0.0             0.000000              0.000000
# Application_1000334415      0.0             0.400061              0.000000
# Application_1000339879      1.0             0.552030              0.409135
#
#                         ...  Activity_O_Sent (mail and online)  \
# Case ID                 ...
# Application_1000086665  ...                           0.000000
# Application_1000158214  ...                           0.000000
# Application_1000311556  ...                           0.000000
# Application_1000334415  ...                           0.566506
# Application_1000339879  ...                           0.566506
#
#                         Activity_O_Sent (online only)  \
# Case ID
# Application_1000086665                       0.354260
# Application_1000158214                       0.394822
# Application_1000311556                       0.407220
# Application_1000334415                       0.000000
# Application_1000339879                       0.000000
#
#                         Activity_W_Assess potential fraud  \
# Case ID
# Application_1000086665                                0.0
# Application_1000158214                                0.0
# Application_1000311556                                0.0
# Application_1000334415                                0.0
# Application_1000339879                                0.0
#
#                         Activity_W_Call after offers  \
# Case ID
# Application_1000086665                      0.400061
# Application_1000158214                      0.407220
# Application_1000311556                      0.000000
# Application_1000334415                      0.568225
# Application_1000339879                      0.566506
#
#                         Activity_W_Call incomplete files  \
# Case ID
# Application_1000086665                          0.407220
# Application_1000158214                          0.742512
# Application_1000311556                          0.407220
# Application_1000334415                          0.407220
# Application_1000339879                          0.000000
#
#                         Activity_W_Complete application  \
# Case ID
# Application_1000086665                         0.409135
# Application_1000158214                         0.000000
# Application_1000311556                         0.000000
# Application_1000334415                         0.576641
# Application_1000339879                         0.566506
#
#                         Activity_W_Handle leads  \
# Case ID
# Application_1000086665                 0.315888
# Application_1000158214                 0.000000
# Application_1000311556                 0.000000
# Application_1000334415                 0.315888
# Application_1000339879                 0.742512
#
#                         Activity_W_Personal Loan collection  \
# Case ID
# Application_1000086665                                  0.0
# Application_1000158214                                  0.0
# Application_1000311556                                  0.0
# Application_1000334415                                  0.0
# Application_1000339879                                  0.0
#
#                         Activity_W_Shortened completion   \
# Case ID
# Application_1000086665                               0.0
# Application_1000158214                               0.0
# Application_1000311556                               0.0
# Application_1000334415                               0.0
# Application_1000339879                               0.0
#
#                         Activity_W_Validate application
# Case ID
# Application_1000086665                         0.000000
# Application_1000158214                         0.742512
# Application_1000311556                         0.400061
# Application_1000334415                         0.576641
# Application_1000339879                         0.576641
#
# [5 rows x 34 columns]

# %%
encoded_data = preparation2.encoded_data
X_train, X_test = train_test_split(encoded_data, test_size=0.2, random_state=42)

# %%
save_csv(X_train, DATA_2_TRAIN_PATH)
save_csv(X_test, DATA_2_TEST_PATH)
